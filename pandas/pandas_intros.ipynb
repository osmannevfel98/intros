# %%
import pandas as pd

# %%
s1 = pd.Series()
s1
# Out:
# Series([], dtype: object)

# %%
s2 = pd.Series([1,2,3,4,5])
s2
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s2.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
s2.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s3 = pd.Series([1,2,3,4,5],index = [10,20,30,40,50])
s3
# Out:
# 10    1
# 20    2
# 30    3
# 40    4
# 50    5
# dtype: int64

# %%
scores = pd.Series([3.2,4.5,2.6,3.5], index=['bob','george','alex','sarah'])
scores
# Out:
# bob       3.2
# george    4.5
# alex      2.6
# sarah     3.5
# dtype: float64

# %%
scores.index
# Out:
# Index(['bob', 'george', 'alex', 'sarah'], dtype='object')

# %%
scores.values
# Out:
# array([3.2, 4.5, 2.6, 3.5])

# %%
d = {'bob':3.2, 'george':4.5, 'alex':2.6, 'sarah':3.5}

# %%
s4 = pd.Series(d)
s4
# Out:
# bob       3.2
# george    4.5
# alex      2.6
# sarah     3.5
# dtype: float64

# %%
s4.index
# Out:
# Index(['bob', 'george', 'alex', 'sarah'], dtype='object')

# %%
s4.values
# Out:
# array([3.2, 4.5, 2.6, 3.5])

# %%
df1 = pd.DataFrame()
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df1)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
students_list = [['Bob','William',26,'Computer Eng',86],
                 ['Emma','Johnson',23,'Math',92],
                 ['Sarah', 'Smith',22,'Chems',95],
                 ['Alex','Brown',21, 'Electrical Eng',82]]
students_df = pd.DataFrame(students_list)
students_df
# Out:
#        0        1   2               3   4
# 0    Bob  William  26    Computer Eng  86
# 1   Emma  Johnson  23            Math  92
# 2  Sarah    Smith  22           Chems  95
# 3   Alex    Brown  21  Electrical Eng  82

# %%
students_df = pd.DataFrame(students_list,columns=['First Name', 'Last Name', 'Age', 'Major', 'Score'])
students_df
# Out:
#   First Name Last Name  Age           Major  Score
# 0        Bob   William   26    Computer Eng     86
# 1       Emma   Johnson   23            Math     92
# 2      Sarah     Smith   22           Chems     95
# 3       Alex     Brown   21  Electrical Eng     82

# %%
students_df = pd.DataFrame(students_list,columns=['First Name', 'Last Name', 'Age', 'Major', 'Score'],
                           index = ['bob@mail.com','emma@mail.com','sarah@mail.com','alex@mail.com'])
students_df
# Out:
#                First Name Last Name  Age           Major  Score
# bob@mail.com          Bob   William   26    Computer Eng     86
# emma@mail.com        Emma   Johnson   23            Math     92
# sarah@mail.com      Sarah     Smith   22           Chems     95
# alex@mail.com        Alex     Brown   21  Electrical Eng     82

# %%
students_dict = { 'First name': ['Bob', 'Emma', 'Sarah', 'Alex'],
                  'Last name': ['William', 'Johnson', 'Smith','Brown'],
                  'Age': [26,23,22,21],
                  'Major': ['Computer Eng','Math','Chems','Electrical Eng'],
                  'Score': [86,92,95,82]
                  }

# %%
students_df2 = pd.DataFrame(students_dict)
students_df2
# Out:
#   First name Last name  Age           Major  Score
# 0        Bob   William   26    Computer Eng     86
# 1       Emma   Johnson   23            Math     92
# 2      Sarah     Smith   22           Chems     95
# 3       Alex     Brown   21  Electrical Eng     82

# %%
students_df2 = pd.DataFrame(students_dict, columns=['Last name', 'Score']) #pandas will show only these two attributes
students_df2
# Out:
#   Last name  Score
# 0   William     86
# 1   Johnson     92
# 2     Smith     95
# 3     Brown     82

# %%
students_df2 = pd.DataFrame(students_dict, columns=['Last name', 'Score', 'City']) #pandas will create new attribute with NaN data
students_df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-079b4d482f0c> in <cell line: 0>()
# ----> 1 students_df2 = pd.DataFrame(students_dict, columns=['Last name', 'Score', 'City']) #pandas will create new attribute with NaN data
#       2 students_df2
#
# NameError: name 'pd' is not defined

# %%
students_df.shape
# Out:
# (4, 5)

# %%
students_df.head(2)
# Out:
#               First Name Last Name  Age         Major  Score
# bob@mail.com         Bob   William   26  Computer Eng     86
# emma@mail.com       Emma   Johnson   23          Math     92

# %%
students_df.tail(2)
# Out:
#                First Name Last Name  Age           Major  Score
# sarah@mail.com      Sarah     Smith   22           Chems     95
# alex@mail.com        Alex     Brown   21  Electrical Eng     82

# %%
students_df.info
# Out:
# <bound method DataFrame.info of                First Name Last Name  Age           Major  Score
# bob@mail.com          Bob   William   26    Computer Eng     86
# emma@mail.com        Emma   Johnson   23            Math     92
# sarah@mail.com      Sarah     Smith   22           Chems     95
# alex@mail.com        Alex     Brown   21  Electrical Eng     82>

# %%
 students_df.describe()
# Out:
#              Age     Score
# count   4.000000   4.00000
# mean   23.000000  88.75000
# std     2.160247   5.85235
# min    21.000000  82.00000
# 25%    21.750000  85.00000
# 50%    22.500000  89.00000
# 75%    23.750000  92.75000
# max    26.000000  95.00000

# %%
df = pd.read_csv('data_new.csv')
df
# Out:
#      first_name last_name experience  score
# 0          Alex     Smith     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Martin     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df1 = pd.read_csv('data_new_01.csv',skiprows=1, names = ['a','b','c','d'])
df1
# Out:
#               a         b        c   d
# 0          Alex     Smith   Python  92
# 1         James     Jones      C++  97
# 2          Mary  Williams   Python  98
# 3      Patricia     Brown     Java  87
# 4      Jennifer    Taylor     HTML  88
# 5         Emily    Davies  Android  90
# 6       Michael    Wilson   Python  91
# 7       Jessica     Evans      C++  95
# 8          John    Thomas   Python  90
# 9        Thomas   Roberts     Java  89
# 10  Christopher    Martin   Python  83
# 11      Barbara       Lee      C++  86
# 12      Matthew  Anderson        R  97
# 13         Mark     White   Python  91
# 14        Nancy    Taylor     Java  96
# 15       Andrew     Smith        R  92

# %%
df2 = pd.read_csv('data_new_02.csv',sep='|') #if seperator is diff. from ,
df2
# Out:
#      first_name last_name experience  score
# 0          Alex     Smith     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Martin     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df3 = pd.read_csv('data_new_03.csv',comment='#', sep='|') # to ignoring comments
df3
# Out:
#      first_name last_name experience  score
# 0          Alex     Smith     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Martin     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df3 = pd.read_csv('data_new_04.csv',skiprows=2, sep='|') #ignoring first 2 lines
df3
# Out:
#      first_name last_name experience  score
# 0          Alex     Smith     Python     92
# 1         James     Jones        C++     97
# 2          Mary  Williams     Python     98
# 3      Patricia     Brown       Java     87
# 4      Jennifer    Taylor       HTML     88
# 5         Emily    Davies    Android     90
# 6       Michael    Wilson     Python     91
# 7       Jessica     Evans        C++     95
# 8          John    Thomas     Python     90
# 9        Thomas   Roberts       Java     89
# 10  Christopher    Martin     Python     83
# 11      Barbara       Lee        C++     86
# 12      Matthew  Anderson          R     97
# 13         Mark     White     Python     91
# 14        Nancy    Taylor       Java     96
# 15       Andrew     Smith          R     92

# %%
df5 = pd.read_csv('data_new_05.csv',header=None, sep='|') #no column names
df5
# Out:
#               0         1        2   3
# 0          Alex     Smith   Python  92
# 1         James     Jones      C++  97
# 2          Mary  Williams   Python  98
# 3      Patricia     Brown     Java  87
# 4      Jennifer    Taylor     HTML  88
# 5         Emily    Davies  Android  90
# 6       Michael    Wilson   Python  91
# 7       Jessica     Evans      C++  95
# 8          John    Thomas   Python  90
# 9        Thomas   Roberts     Java  89
# 10  Christopher    Martin   Python  83
# 11      Barbara       Lee      C++  86
# 12      Matthew  Anderson        R  97
# 13         Mark     White   Python  91
# 14        Nancy    Taylor     Java  96
# 15       Andrew     Smith        R  92

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
ages = df['Age']
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
type(ages)
# Out:
# pandas.core.series.Series

# %%
ages.mean() #avg of ages
# Out:
# 29.69911764705882

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.Age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df.iloc[0,[1,4]]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
df.loc[0,['Survived','Sex']]
# Out:
# Survived       0
# Sex         male
# Name: 0, dtype: object

# %%
df.iloc[:5,:3] #first 5 rows, first 3 columns
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3

# %%
df.iloc[[0,-1],-3:] #first and last rows, last 3 columns
# Out:
#      Fare Cabin Embarked
# 0    7.25   NaN        S
# 890  7.75   NaN        Q

# %%
df.loc[5:10,'Name':'Ticket'] #row between 5 to 10, column between Name and Ticket
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket
# 5       0   330877
# 6       0    17463
# 7       1   349909
# 8       2   347742
# 9       0   237736
# 10      1  PP 9549

# %%
df.Sex == 'male'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Sex, Length: 891, dtype: bool

# %%
df.loc[df.Sex == 'male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.loc[(df.Sex == 'female') & (df.Age > 35)] #females older than 35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 11            12         1       1
# 15            16         1       2
# 25            26         1       3
# 40            41         0       3
# ..           ...       ...     ...
# 862          863         1       1
# 865          866         1       2
# 871          872         1       1
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 25   Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
# 40      Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Data preprocessing

# %%
df.isna() # check if elements are NaN or not
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isna().any() #checks each attrb if has NaN value
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df2 = df.dropna(axis=0) #drops all nan rows
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True) #drops all nan rows
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('titanic.csv')

# %%
df.fillna(0) #fill NaN values replaced with 0
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('titanic.csv')
df3 = df.fillna(df.mean(numeric_only=True)) #replacing NaN values with the means of these columns (only numeric ones)
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df4 = df3.fillna(df3.mode().iloc[0]) #iloc is for getting the most frequent value
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df4.isna().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age            False
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.duplicated().any() #check duplicate rows
# Out:
# False

# %%
df = pd.read_csv('employees.csv')
df.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
df.rename({'First Name':'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus', 'Senior Management':'Senior_Management'}) #will not change
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df.rename({'First Name':'First_Name', 'Start Date':'Start_Date', 'Last Login Time':'Last_Login_Time',
       'Bonus %':'Bonus', 'Senior Management':'Senior_Management'},axis=1,inplace=True)
df
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
df['Bonus2'] = df.Bonus.round() #add new column
df
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2
# 0                True             Marketing     7.0
# 1                True                   NaN     4.0
# ...

# %%
import numpy as np

# %%
df['random'] = pd.Series(np.random.randint(0,10,1000)) #add new column
df
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       9
# ...

# %%
df2 = df.iloc[:2]
df2
# Out:
#   First_Name Gender Start_Date Last_Login_Time  Salary  Bonus  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308  6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933  4.170
#
#   Senior_Management       Team  Bonus2  random
# 0              True  Marketing     7.0       9
# 1              True        NaN     4.0       9

# %%
df3 = pd.concat((df,df2),axis = 0) #adding df2 to df s end
df3
# Out:
#     First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2        Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3        Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4        Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ..         ...     ...        ...             ...     ...     ...
# 997    Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 0      Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1       Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#     Senior_Management                  Team  Bonus2  random
# 0                True             Marketing     7.0       9
# ...

# %%
df3 = pd.concat((df,df2),axis = 0,ignore_index=True) #fixing the index
df3
# Out:
#      First_Name  Gender Start_Date Last_Login_Time  Salary   Bonus  \
# 0       Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1        Thomas    Male  3/31/1996         6:53 AM   61933   4.170
# 2         Maria  Female  4/23/1993        11:17 AM  130590  11.858
# 3         Jerry    Male   3/4/2005         1:00 PM  138705   9.340
# 4         Larry    Male  1/24/1998         4:47 PM  101004   1.389
# ...         ...     ...        ...             ...     ...     ...
# 997     Russell    Male  5/20/2013        12:39 PM   96914   1.421
# 998       Larry    Male  4/20/2013         4:45 PM   60500  11.985
# 999      Albert    Male  5/15/2012         6:24 PM  129949  10.169
# 1000    Douglas    Male   8/6/1993        12:42 PM   97308   6.945
# 1001     Thomas    Male  3/31/1996         6:53 AM   61933   4.170
#
#      Senior_Management                  Team  Bonus2  random
# 0                 True             Marketing     7.0       9
# ...

# %%
df4 = df.drop(['First_Name'],axis=1) #dropping columns
df4
# Out:
#      Gender  Start_Date Last_Login_Time  Salary   Bonus Senior_Management  \
# 0      Male    8/6/1993        12:42 PM   97308   6.945              True
# 1      Male   3/31/1996         6:53 AM   61933   4.170              True
# 2    Female   4/23/1993        11:17 AM  130590  11.858             False
# 3      Male    3/4/2005         1:00 PM  138705   9.340              True
# 4      Male   1/24/1998         4:47 PM  101004   1.389              True
# ..      ...         ...             ...     ...     ...               ...
# 995     NaN  11/23/2014         6:09 AM  132483  16.655             False
# 996    Male   1/31/1984         6:30 AM   42392  19.675             False
# 997    Male   5/20/2013        12:39 PM   96914   1.421             False
# 998    Male   4/20/2013         4:45 PM   60500  11.985             False
# 999    Male   5/15/2012         6:24 PM  129949  10.169              True
#
#                      Team  Bonus2  random
# ...

# %%
df.drop(range(5),axis=0) #dropping rows
# Out:
#     First_Name  Gender  Start_Date Last_Login_Time  Salary   Bonus  \
# 5       Dennis    Male   4/18/1987         1:35 AM  115163  10.125
# 6         Ruby  Female   8/17/1987         4:20 PM   65476  10.012
# 7          NaN  Female   7/20/2015        10:43 AM   45906  11.598
# 8       Angela  Female  11/22/2005         6:29 AM   95570  18.523
# 9      Frances  Female    8/8/2002         6:51 AM  139852   7.524
# ..         ...     ...         ...             ...     ...     ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483  16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392  19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914   1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500  11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949  10.169
#
#     Senior_Management                  Team  Bonus2  random
# 5               False                 Legal    10.0       7
# ...

# %%
df = pd.read_csv('employees.csv')

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    431
# Male      424
# Name: count, dtype: int64

# %%
df.Gender.isna().sum()
# Out:
# 145

# %%
df['Gender2'] = pd.Categorical(df.Gender)
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2
# 0              True        Marketing    Male
# 1              True              NaN    Male
# 2             False          Finance  Female
# 3              True          Finance    Male
# 4              True  Client Services    Male

# %%
df.memory_usage()
# Out:
# Index                 132
# First Name           8000
# Gender               8000
# Start Date           8000
# Last Login Time      8000
# Salary               8000
# Bonus %              8000
# Senior Management    8000
# Team                 8000
# Gender2              1124
# dtype: int64

# %%
import random

# %%
df['Score'] = pd.Series(random.choices(['Very Low','Low','Medium','High','Very High'],k=1000))
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team Gender2      Score
# 0              True        Marketing    Male  Very High
# 1              True              NaN    Male     Medium
# 2             False          Finance  Female        Low
# 3              True          Finance    Male     Medium
# 4              True  Client Services    Male       High

# %%
df['Score2'] = pd.Categorical(df.Score,categories=['Very Low','Low','Medium','High','Very High'],ordered=True) #hierarchy

# %%
df.Score2 > 'Medium'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Score2, Length: 1000, dtype: bool

# %%
sum(df.Score2>'Medium')
# Out:
# 403

# %%
df.Salary.min()
# Out:
# 35013

# %%
df.Salary.max()
# Out:
# 149908

# %%
pd.cut(df.Salary, bins = [35000,50000,75000,100000,125000,150000],
                  labels=['Very Low','Low','Medium','High','Very High']) #classifying salaries
# Out:
# 0         Medium
# 1            Low
# 2      Very High
# 3      Very High
# 4           High
#          ...
# 995    Very High
# 996     Very Low
# 997       Medium
# 998          Low
# 999    Very High
# Name: Salary, Length: 1000, dtype: category
# Categories (5, object): ['Very Low' < 'Low' < 'Medium' < 'High' < 'Very High']
